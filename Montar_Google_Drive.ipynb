# %% [markdown]
# <a href="https://colab.research.google.com/github/renatotrapp/PowerBI-DataScience/blob/master/Montar_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive
