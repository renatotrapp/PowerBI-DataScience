# %% [markdown]
# <a href="https://colab.research.google.com/github/renatotrapp/PowerBI-DataScience/blob/master/PrimeiroTesteAcessoPranilhaNoGoogleDrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import pandas as pd
df = pd.read_excel('/content/drive/My Drive/Estudo Python/Matriz_BNCC_Marketing_Escola.xlsx')
df
# Out:
# Mounted at /content/drive
#    Área do Conhecimento                  Componente (BNCC)  \
# 0            Linguagens                  Língua Portuguesa
# 1            Matemática                         Matemática
# 2  Ciências da Natureza        Biologia / Física / Química
# 3      Ciências Humanas  História / Geografia / Sociologia
# 4       Projeto de Vida                      (Obrigatório)
#
#                    Habilidade Foco (Exemplo)  \
# 0     Analisar criticamente textos e mídias.
# 1  Raciocínio lógico e modelagem financeira.
# 2   Sustentabilidade e análise de fenômenos.
# 3               Ética, política e sociedade.
# 4               Autoconhecimento e carreira.
#
#                Diferencial da Escola (O 'Como')  \
# 0      Oficina de Podcast e Jornalismo Digital.
# 1  Educação Financeira com Python ou Planilhas.
# 2       Horta hidropônica ou Laboratório Maker.
# 3      Simulações da ONU e debates filosóficos.
# 4   Mentorias individuais e Testes Vocacionais.
#
# ...
